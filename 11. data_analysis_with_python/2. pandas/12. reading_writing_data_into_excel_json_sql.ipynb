# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df= pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.shape
# Out:
# (88883, 84)

# %%
filter1 = (df['Country']== 'Bangladesh')
bd_df= df.loc[filter1]

# %%
bd_df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 42                             I am a developer by profession      Yes
# 171                    I am a student who is learning to code      Yes
# 300                    I am a student who is learning to code       No
# 324                            I am a developer by profession      Yes
# 690         I used to be a developer by profession, but no...       No
# ...                                                       ...      ...
# 40072                                                     NaN      Yes
# 62740                                                     NaN       No
# 64910                                                     NaN       No
# 78004                                                     NaN      Yes
# 81624                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
#exporting the new df
#comma seperated value
bd_df.to_csv("data/bd_df.csv")

# %%
#data seperated by tab \t we can make the seperator anything like - double --
bd_df.to_csv("data/bd_df.tsv", sep= '\t')

# %%
#we can also add that sep argument in the read csv column where we read the csv file

# %% [markdown]
# #### wroking with excel file

# %%
#packages we need for excel
# %pip install xlwt openpyxl xlrd

# %%
bd_df.to_excel('data/bd_df.xlsx')

# %%
#we can read the excel file like that
df2 = pd.read_excel('data/bd_df.xlsx', index_col='Respondent')

# %%
df2
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 42                             I am a developer by profession      Yes
# 171                    I am a student who is learning to code      Yes
# 300                    I am a student who is learning to code       No
# 324                            I am a developer by profession      Yes
# 690         I used to be a developer by profession, but no...       No
# ...                                                       ...      ...
# 40072                                                     NaN      Yes
# 62740                                                     NaN       No
# 64910                                                     NaN       No
# 78004                                                     NaN      Yes
# 81624                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
#converting the file into json 
bd_df.to_json('data/bd_df.json',orient = 'records', lines = True)

# %%
df3= pd.read_json('data/bd_df.json', lines = True, orient= 'records')

# %%
df3
# Out:
#                                             MainBranch Hobbyist  \
# 0                       I am a developer by profession      Yes
# 1               I am a student who is learning to code      Yes
# 2               I am a student who is learning to code       No
# 3                       I am a developer by profession      Yes
# 4    I used to be a developer by profession, but no...       No
# ..                                                 ...      ...
# 600                                               None      Yes
# 601                                               None       No
# 602                                               None       No
# 603                                               None      Yes
# 604                                               None      Yes
#
#                                            OpenSourcer  \
# 0    Less than once a month but more than once per ...
# 1                              Less than once per year
# ...

# %%
df3
# Out:
#                                             MainBranch Hobbyist  \
# 0                       I am a developer by profession      Yes
# 1               I am a student who is learning to code      Yes
# 2               I am a student who is learning to code       No
# 3                       I am a developer by profession      Yes
# 4    I used to be a developer by profession, but no...       No
# ..                                                 ...      ...
# 600                                               None      Yes
# 601                                               None       No
# 602                                               None       No
# 603                                               None      Yes
# 604                                               None      Yes
#
#                                            OpenSourcer  \
# 0    Less than once a month but more than once per ...
# 1                              Less than once per year
# ...

# %%
#read and write data from sql database
# #package we need for sql 
# %pip install SQLAlchemy psycopg2-binary

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
# engine = create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')

# %%
# india_df.to_sql('sample_table', engine, if_exists='replace')

# %%
# sql_df = pd.read_sql('sample_table', engine, index_col='Respondent')

# %%
# sql_df.head()

# %%
# sql_df = pd.read_sql_query('SELECT * FROM sample_table', engine, index_col='Respondent')

# %%
# sql_df.head()

# %%
#reading url
import pandas as pd
df3 = pd.read_json('https://raw.githubusercontent.com/rhs2/mlbootcamp/refs/heads/master/11.%20data_analysis_with_python/2.%20pandas/data/posts.json')

# %%
df3
# Out:
#                                               title  \
# 0                                   My Updated Post
# 1                                     A Second Post
# 2                      Top 5 Programming Lanaguages
# 3                      Sublime Text Tips and Tricks
# 4                                  Best Python IDEs
# 5                Flask vs Django - Which Is Better?
# 6         You Won't Believe These Clickbait Titles!
# 7         These Beers Will Improve Your Programming
# 8                          List of PyCon 2018 Talks
# 9     How Dogs in the Workplace Boosts Productivity
# 10                    The Best Programming Podcasts
# 11                         Tips for Public Speaking
# 12              Best Programmers Throughout History
# 13                  How To Create A YouTube Channel
# 14                           How I Record My Videos
# 15                               Python and Physics
# 16            Just A Few More Healines Should Do It
# ...
